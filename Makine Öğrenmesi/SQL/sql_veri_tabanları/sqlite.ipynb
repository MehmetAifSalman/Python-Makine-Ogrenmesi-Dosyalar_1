# %%
# %%!
# pip install --trusted-host pypi.org ipython-sql
# Out:
# ['Collecting ipython-sql',
#  '  Downloading ipython_sql-0.5.0-py3-none-any.whl (20 kB)',
#  'Collecting sqlparse',
#  '  Downloading sqlparse-0.4.3-py3-none-any.whl (42 kB)',
#  'Requirement already satisfied: six in c:\\users\\sl\\anaconda3\\lib\\site-packages (from ipython-sql) (1.16.0)',
#  'Collecting sqlalchemy>=2.0',
#  '  Downloading SQLAlchemy-2.0.9-cp39-cp39-win_amd64.whl (2.0 MB)',
#  'Requirement already satisfied: ipython-genutils in c:\\users\\sl\\anaconda3\\lib\\site-packages (from ipython-sql) (0.2.0)',
#  'Collecting prettytable',
#  '  Downloading prettytable-3.6.0-py3-none-any.whl (27 kB)',
#  'Requirement already satisfied: ipython in c:\\users\\sl\\anaconda3\\lib\\site-packages (from ipython-sql) (8.2.0)',
#  'Requirement already satisfied: greenlet!=0.4.17 in c:\\users\\sl\\anaconda3\\lib\\site-packages (from sqlalchemy>=2.0->ipython-sql) (1.1.1)',
#  'Collecting typing-extensions>=4.2.0',
#  '  Downloading typing_extensions-4.5.0-py3-none-any.whl (27 kB)',
# ...

# %%
# %load_ext sql

# %%
# %sql sqlite:///vbo.db

# %%
# %%sql
# SELECT * FROM Customers LIMIT 3;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany'),
#  (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico')]

# %%
# %%sql
# CREATE TABLE yeni_tablo(firstname varchar(20),
#                        lastname varchar(20));
# Out:
#  * sqlite:///vbo.db
# Done.
# []

# %%
# %%sql
# INSERT INTO yeni_tablo values("Ali","Uzaya_Git");
# Out:
#  * sqlite:///vbo.db
# 1 rows affected.
# []

# %%
# %%sql
# SELECT * FROM yeni_tablo;
# Out:
#  * sqlite:///vbo.db
# Done.
# [('Mehmet', 'Soyadı\r\n'), ('Ali', 'Uzaya_Git'), ('Işık', 'Süte_Devam')]

# %%
# %%sql
# INSERT INTO yeni_tablo values("Işık","Süte_Devam");
# Out:
#  * sqlite:///vbo.db
# 1 rows affected.
# []

# %%
# %%sql
# SELECT * FROM Products LIMIT 5;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(1, 'Chais', 1, 1, '10 boxes x 20 bags', 18),
#  (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19),
#  (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10),
#  (4, "Chef Anton's Cajun Seasoning", 2, 2, '48 - 6 oz jars', 22),
#  (5, "Chef Anton's Gumbo Mix", 2, 2, '36 boxes', 21)]

# %%
# %%sql
# SELECT name FROM sqlite_master WHERE type = "table";
# Out:
#  * sqlite:///vbo.db
# Done.
# [('Products',),
#  ('Categories',),
#  ('Customers',),
#  ('Employees',),
#  ('OrderDetails',),
#  ('Orders',),
#  ('Shippers',),
#  ('Suppliers',),
#  ('yeni_tablo',)]

# %%
# %%sql
# SELECT * FROM Customers where 1=0;
# Out:
#  * sqlite:///vbo.db
# Done.
# []

# %%
# %%sql
# SELECT CustomerName,City FROM Customers LIMIT 3;
# Out:
#  * sqlite:///vbo.db
# Done.
# [('Alfreds Futterkiste', 'Berlin'),
#  ('Ana Trujillo Emparedados y helados', 'México D.F.'),
#  ('Antonio Moreno Taquería', 'México D.F.')]

# %%
# %%sql
# SELECT Price ,Price * 2,Price*3-100 AS islemli_price FROM Products LIMIT 3;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(18, 36, -46), (19, 38, -43), (10, 20, -70)]

# %%
# %%sql
# SELECT COUNT(*) AS satir_sayisi FROM Customers;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(91,)]

# %%
# %%sql
# SELECT * from Products ORDER by Price limit 10;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(13, 'Konbu', 6, 8, '2 kg box', 6),
#  (52, 'Filo Mix', 24, 5, '16 - 2 kg boxes', 7),
#  (23, 'Tunnbröd', 9, 5, '12 - 250 g pkgs.', 9),
#  (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10),
#  (21, "Sir Rodney's Scones", 8, 3, '24 pkgs. x 4 pieces', 10),
#  (74, 'Longlife Tofu', 4, 7, '5 kg pkg.', 10),
#  (46, 'Spegesild', 21, 8, '4 - 450 g glasses', 12),
#  (58, 'Escargots de Bourgogne', 27, 8, '24 pieces', 13),
#  (77, 'Original Frankfurter grüne Soße', 12, 2, '12 boxes', 13),
#  (25, 'NuNuCa Nuß-Nougat-Creme', 11, 3, '20 - 450 g glasses', 14)]

# %%
# %%sql
# select * from Customers limit 10;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany'),
#  (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico'),
#  (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK'),
#  (5, 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden'),
#  (6, 'Blauer See Delikatessen', 'Hanna Moos', 'Forsterstr. 57', 'Mannheim', '68306', 'Germany'),
#  (7, 'Blondel père et fils', 'Frédérique Citeaux', '24, place Kléber', 'Strasbourg', '67000', 'France'),
#  (8, 'Bólido Comidas preparadas', 'Martín Sommer', 'C/ Araquil, 67', 'Madrid', '28023', 'Spain'),
#  (9, "Bon app'", 'Laurence Lebihans', '12, rue des Bouchers', 'Marseille', '13008', 'France'),
# ...

# %%
# %%sql
# select * from Customers where not City = "Berlin" limit 10;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico'),
#  (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK'),
#  (5, 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden'),
#  (6, 'Blauer See Delikatessen', 'Hanna Moos', 'Forsterstr. 57', 'Mannheim', '68306', 'Germany'),
#  (7, 'Blondel père et fils', 'Frédérique Citeaux', '24, place Kléber', 'Strasbourg', '67000', 'France'),
#  (8, 'Bólido Comidas preparadas', 'Martín Sommer', 'C/ Araquil, 67', 'Madrid', '28023', 'Spain'),
#  (9, "Bon app'", 'Laurence Lebihans', '12, rue des Bouchers', 'Marseille', '13008', 'France'),
#  (10, 'Bottom-Dollar Marketse', 'Elizabeth Lincoln', '23 Tsawassen Blvd.', 'Tsawassen', 'T2F 8M4', 'Canada'),
# ...

# %%
# %%sql
# SELECT * FROM Customers where PostalCode > 5021;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico'),
#  (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK'),
#  (5, 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden'),
#  (6, 'Blauer See Delikatessen', 'Hanna Moos', 'Forsterstr. 57', 'Mannheim', '68306', 'Germany'),
#  (7, 'Blondel père et fils', 'Frédérique Citeaux', '24, place Kléber', 'Strasbourg', '67000', 'France'),
#  (10, 'Bottom-Dollar Marketse', 'Elizabeth Lincoln', '23 Tsawassen Blvd.', 'Tsawassen', 'T2F 8M4', 'Canada'),
#  (11, "B's Beverages", 'Victoria Ashworth', 'Fauntleroy Circus', 'London', 'EC2 5NT', 'UK'),
#  (13, 'Centro comercial Moctezuma', 'Francisco Chang', 'Sierras de Granada 9993', 'México D.F.', '5022', 'Mexico'),
#  (16, 'Consolidated Holdings', 'Elizabeth Brown', 'Berkeley Gardens 12 Brewery', 'London', 'WX1 6LT', 'UK'),
# ...

# %%
# %%sql
# SELECT * FROM Customers;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany'),
#  (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico'),
#  (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK'),
#  (5, 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden'),
#  (6, 'Blauer See Delikatessen', 'Hanna Moos', 'Forsterstr. 57', 'Mannheim', '68306', 'Germany'),
#  (7, 'Blondel père et fils', 'Frédérique Citeaux', '24, place Kléber', 'Strasbourg', '67000', 'France'),
#  (8, 'Bólido Comidas preparadas', 'Martín Sommer', 'C/ Araquil, 67', 'Madrid', '28023', 'Spain'),
#  (9, "Bon app'", 'Laurence Lebihans', '12, rue des Bouchers', 'Marseille', '13008', 'France'),
# ...

# %%
# %%sql
# SELECT count(CustomerID), Country from Customers GROUP BY Country;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(3, 'Argentina'),
#  (2, 'Austria'),
#  (2, 'Belgium'),
#  (9, 'Brazil'),
#  (3, 'Canada'),
#  (2, 'Denmark'),
#  (2, 'Finland'),
#  (11, 'France'),
#  (11, 'Germany'),
#  (1, 'Ireland'),
#  (3, 'Italy'),
#  (5, 'Mexico'),
#  (1, 'Norway'),
#  (1, 'Poland'),
#  (2, 'Portugal'),
#  (5, 'Spain'),
#  (2, 'Sweden'),
#  (2, 'Switzerland'),
#  (7, 'UK'),
#  (13, 'USA'),
#  (4, 'Venezuela')]

# %%
# %%sql
# SELECT name FROM qslite_master type = "table";
# Out:
#  * sqlite:///vbo.db
# (sqlite3.OperationalError) near "=": syntax error
# [SQL: SELECT name FROM qslite_master type = "table";]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
import pandas as pd

# %%
import sqlite3

# %%
conn = sqlite3.connect("vbo.db")

# %%
c = conn.cursor()

# %%
pd.read_sql("SELECT COUNT(CustomerID) AS Musteri_Sayisi, Country FROM Customers GROUP BY Country;",conn)
# Out:
#     Musteri_Sayisi      Country
# 0                3    Argentina
# 1                2      Austria
# 2                2      Belgium
# 3                9       Brazil
# 4                3       Canada
# 5                2      Denmark
# 6                2      Finland
# 7               11       France
# 8               11      Germany
# 9                1      Ireland
# 10               3        Italy
# 11               5       Mexico
# 12               1       Norway
# 13               1       Poland
# 14               2     Portugal
# 15               5        Spain
# 16               2       Sweden
# 17               2  Switzerland
# 18               7           UK
# 19              13          USA
# 20               4    Venezuela

# %%
#conn.close()

# %%
c.execute("SELECT CustomerName FROM Customers LIMIT 5 ;")

# %%
c.fetchone()
# Out:
# ('Alfreds Futterkiste',)

# %%
c.fetchall()
# Out:
# [('Ana Trujillo Emparedados y helados',),
#  ('Antonio Moreno Taquería',),
#  ('Around the Horn',),
#  ('Berglunds snabbköp',)]

# %%
# %%sql
# SELECT Count(DISTINCT CustomerID) FROM Orders
# Out:
#  * sqlite:///vbo.db
# Done.
# [(74,)]

# %%
# %%sql
# SELECT Count(DISTINCT CustomerID) From Orders;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(74,)]

# %%
# %%sql
# SELECT Count(Customers.CustomerID) as MS,Country FROM Customers GROUP BY Country ORDER BY MS;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(1, 'Ireland'),
#  (1, 'Norway'),
#  (1, 'Poland'),
#  (2, 'Austria'),
#  (2, 'Belgium'),
#  (2, 'Denmark'),
#  (2, 'Finland'),
#  (2, 'Portugal'),
#  (2, 'Sweden'),
#  (2, 'Switzerland'),
#  (3, 'Argentina'),
#  (3, 'Canada'),
#  (3, 'Italy'),
#  (4, 'Venezuela'),
#  (5, 'Mexico'),
#  (5, 'Spain'),
#  (7, 'UK'),
#  (9, 'Brazil'),
#  (11, 'France'),
#  (11, 'Germany'),
#  (13, 'USA')]

# %%
# %%sql
# SELECT * FROM Customers WHERE Country = "Brazil" OR Country = "USA"
# Out:
#  * sqlite:///vbo.db
# Done.
# [(15, 'Comércio Mineiro', 'Pedro Afonso', 'Av. dos Lusíadas, 23', 'São Paulo', '05432-043', 'Brazil'),
#  (21, 'Familia Arquibaldo', 'Aria Cruz', 'Rua Orós, 92', 'São Paulo', '05442-030', 'Brazil'),
#  (31, 'Gourmet Lanchonetes', 'André Fonseca', 'Av. Brasil, 442', 'Campinas', '04876-786', 'Brazil'),
#  (32, 'Great Lakes Food Market', 'Howard Snyder', '2732 Baker Blvd.', 'Eugene', '97403', 'USA'),
#  (34, 'Hanari Carnes', 'Mario Pontes', 'Rua do Paço, 67', 'Rio de Janeiro', '05454-876', 'Brazil'),
#  (36, 'Hungry Coyote Import Store', 'Yoshi Latimer', 'City Center Plaza 516 Main St.', 'Elgin', '97827', 'USA'),
#  (43, 'Lazy K Kountry Store', 'John Steel', '12 Orchestra Terrace', 'Walla Walla', '99362', 'USA'),
#  (45, "Let's Stop N Shop", 'Jaime Yorres', '87 Polk St. Suite 5', 'San Francisco', '94117', 'USA'),
#  (48, 'Lonesome Pine Restaurant', 'Fran Wilson', '89 Chiaroscuro Rd.', 'Portland', '97219', 'USA'),
# ...

# %%
# %%sql
# SELECT count(*) AS Musteri_Sayisi , Country, City FROM Customers GROUP BY Country , City;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(3, 'Argentina', 'Buenos Aires'),
#  (1, 'Austria', 'Graz'),
#  (1, 'Austria', 'Salzburg'),
#  (1, 'Belgium', 'Bruxelles'),
#  (1, 'Belgium', 'Charleroi'),
#  (1, 'Brazil', 'Campinas'),
#  (1, 'Brazil', 'Resende'),
#  (3, 'Brazil', 'Rio de Janeiro'),
#  (4, 'Brazil', 'São Paulo'),
#  (1, 'Canada', 'Montréal'),
#  (1, 'Canada', 'Tsawassen'),
#  (1, 'Canada', 'Vancouver'),
#  (1, 'Denmark', 'København'),
#  (1, 'Denmark', 'Århus'),
#  (1, 'Finland', 'Helsinki'),
#  (1, 'Finland', 'Oulu'),
#  (1, 'France', 'Lille'),
#  (1, 'France', 'Lyon'),
#  (1, 'France', 'Marseille'),
#  (2, 'France', 'Nantes'),
#  (2, 'France', 'Paris'),
#  (1, 'France', 'Reims'),
#  (1, 'France', 'Strasbourg'),
#  (1, 'France', 'Toulouse'),
#  (1, 'France', 'Versailles'),
#  (1, 'Germany', 'Aachen'),
#  (1, 'Germany', 'Berlin'),
#  (1, 'Germany', 'Brandenburg'),
#  (1, 'Germany', 'Cunewalde'),
#  (1, 'Germany', 'Frankfurt a.M.'),
#  (1, 'Germany', 'Köln'),
# ...

# %%
# %%sql
# SELECT * FROM Customers Where Address LIKE "%da%"
# Out:
#  * sqlite:///vbo.db
# Done.
# [(2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (13, 'Centro comercial Moctezuma', 'Francisco Chang', 'Sierras de Granada 9993', 'México D.F.', '5022', 'Mexico'),
#  (15, 'Comércio Mineiro', 'Pedro Afonso', 'Av. dos Lusíadas, 23', 'São Paulo', '05432-043', 'Brazil'),
#  (28, 'Furia Bacalhau e Frutos do Mar', 'Lino Rodriguez', 'Jardim das rosas n. 32', 'Lisboa', '1675', 'Portugal'),
#  (54, 'Océano Atlántico Ltda.', 'Yvonne Moncada', 'Ing. Gustavo Moncada 8585 Piso 20-A', 'Buenos Aires', '1010', 'Argentina'),
#  (60, 'Princesa Isabel Vinhoss', 'Isabel de Castro', 'Estrada da saúde n. 58', 'Lisboa', '1756', 'Portugal'),
#  (61, 'Que Delícia', 'Bernardo Batista', 'Rua da Panificadora, 12', 'Rio de Janeiro', '02389-673', 'Brazil'),
#  (62, 'Queen Cozinha', 'Lúcia Carvalho', 'Alameda dos Canàrios, 891', 'São Paulo', '05487-020', 'Brazil'),
# ...

# %%
# %%sql
# SELECT CustomerName from Customers WHERE Country = "Germany" AND City = "Berlin"
# Out:
#  * sqlite:///vbo.db
# Done.
# [('Alfreds Futterkiste',)]

# %%
# %%sql
# SELECT CustomerName FROM Customers WHERE (CustomerName LIKE "%in%") and Country = "Canada";
# Out:
#  * sqlite:///vbo.db
# Done.
# [('Laughing Bacchus Wine Cellars',)]

# %%
# %%sql
# SELECT CustomerName FROM Customers WHERE CustomerName LIKE '%in%' AND Country = 'Canada';
# Out:
#  * sqlite:///vbo.db
# Done.
# [('Laughing Bacchus Wine Cellars',)]

# %%
# %%sql
# SELECT ProductName , Price from Products where Price  between 40 AND 90 ORDER BY Price;
# Out:
#  * sqlite:///vbo.db
# Done.
# [('Northwoods Cranberry Sauce', 40),
#  ('Genen Shouyu', 43),
#  ('Teatime Chocolate Biscuits', 43),
#  ('Guaraná Fantástica', 43),
#  ('Schoggi Schokolade', 43),
#  ('Geitost', 43),
#  ('Boston Crab Meat', 43),
#  ('Røgede sild', 43),
#  ('Zaanse koeken', 43),
#  ('Ravioli Angelo', 43),
#  ("Sirop d'érable", 43),
#  ('Vegie-spread', 43),
#  ('Louisiana Fiery Hot Pepper Sauce', 43),
#  ('Rössle Sauerkraut', 45),
#  ('Scottish Longbreads', 45),
#  ('Ipoh Coffee', 46),
#  ('Tarte au sucre', 49),
#  ('Manjimup Dried Apples', 53),
#  ('Raclette Courdavault', 55),
#  ('Carnarvon Tigers', 62),
#  ("Sir Rodney's Marmalade", 81)]

# %%
# %%sql
# SELECT ProductName AS urun_ismi, Price AS urun_fiyati,
# Price * Price AS urun_fiyatının_karesi FROM Products
# WHERE Price >= 30;
# Out:
#  * sqlite:///vbo.db
# Done.
# [("Uncle Bob's Organic Dried Pears", 30, 900),
#  ('Northwoods Cranberry Sauce', 40, 1600),
#  ('Mishi Kobe Niku', 97, 9409),
#  ('Ikura', 31, 961),
#  ('Queso Manchego La Pastora', 38, 1444),
#  ('Genen Shouyu', 43, 1849),
#  ('Alice Mutton', 39, 1521),
#  ('Carnarvon Tigers', 62, 3844),
#  ('Teatime Chocolate Biscuits', 43, 1849),
#  ("Sir Rodney's Marmalade", 81, 6561),
#  ('Guaraná Fantástica', 43, 1849),
#  ('Gumbär Gummibärchen', 31, 961),
#  ('Schoggi Schokolade', 43, 1849),
#  ('Rössle Sauerkraut', 45, 2025),
#  ('Thüringer Rostbratwurst', 123, 15129),
#  ('Gorgonzola Telino', 435, 189225),
#  ('Mascarpone Fabioli', 32, 1024),
#  ('Geitost', 43, 1849),
#  ('Côte de Blaye', 263, 69169),
#  ('Boston Crab Meat', 43, 1849),
#  ('Ipoh Coffee', 46, 2116),
#  ('Røgede sild', 43, 1849),
#  ('Zaanse koeken', 43, 1849),
#  ('Manjimup Dried Apples', 53, 2809),
#  ('Perth Pasties', 32, 1024),
#  ('Gnocchi di nonna Alice', 38, 1444),
# ...

# %%
# %%sql
# SELECT * from Products LEFT JOIN Categories ON Categories.CategoryID = Products.CategoryID
# Out:
#  * sqlite:///vbo.db
# Done.
# [(1, 'Chais', 1, 1, '10 boxes x 20 bags', 18, 1, 'Beverages', 'Soft drinks, coffees, teas, beers, and ales'),
#  (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19, 1, 'Beverages', 'Soft drinks, coffees, teas, beers, and ales'),
#  (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10, 2, 'Condiments', 'Sweet and savory sauces, relishes, spreads, and seasonings'),
#  (4, "Chef Anton's Cajun Seasoning", 2, 2, '48 - 6 oz jars', 22, 2, 'Condiments', 'Sweet and savory sauces, relishes, spreads, and seasonings'),
#  (5, "Chef Anton's Gumbo Mix", 2, 2, '36 boxes', 21, 2, 'Condiments', 'Sweet and savory sauces, relishes, spreads, and seasonings'),
#  (6, "Grandma's Boysenberry Spread", 3, 2, '12 - 8 oz jars', 25, 2, 'Condiments', 'Sweet and savory sauces, relishes, spreads, and seasonings'),
#  (7, "Uncle Bob's Organic Dried Pears", 3, 7, '12 - 1 lb pkgs.', 30, 7, 'Produce', 'Dried fruit and bean curd'),
# ...

# %%
# %%sql
# SELECT AVG(Price) from Products LEFT JOIN Categories ON Categories.CategoryID = Products.CategoryID WHERE CategoryName = "Beverages";
# Out:
#  * sqlite:///vbo.db
# Done.
# [(42.75,)]

# %%
# %%sql
# SELECT * FROM Customers
# LEFT JOIN
# (Orders left join(OrderDetails LEFT JOIN Products ON OrderDetail.ProductID = Products.ProductID)
# ON Orders.OrderID = OrderDeatils.OrderID)
# ON Customers.CustomerID = Orders.OrderID
# Out:
#  * sqlite:///vbo.db
# (sqlite3.OperationalError) no such column: OrderDetail.ProductID
# [SQL: SELECT * FROM Customers
# LEFT JOIN
# (Orders left join(OrderDetails LEFT JOIN Products ON OrderDetail.ProductID = Products.ProductID)
# ON Orders.OrderID = OrderDeatils.OrderID)
# ON Customers.CustomerID = Orders.OrderID]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# %%sql
# SELECT SUM(p.Price)
# FROM Orders o
# LEFT JOIN OrderDetails od on o.OrderID = od.OrderID
# LEFT JOIN Products p on od.ProductID = p.ProductID
# LEFT JOIN Customers cu on o.CustomerID = cu.CustomerID where cu.Country = 'USA';
# Out:
#  * sqlite:///vbo.db
# Done.
# [(3762,)]

# %%
AVG(Products.Price)

# %%
# Out:
#  * sqlite:///vbo.db
# (sqlite3.OperationalError) no such column: Products.Country
# [SQL: SELECT * , CategoryName FROM Products LEFT JOIN Categories ON Products.CategoryID = Categories.CategoryID
# WHERE Products.Country = "Germany" GROUP BY Categories.CategoryName;]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# %%sql
# SELECT ca.CategoryName, AVG(p.Price)
# FROM Orders o
# LEFT JOIN OrderDetails od on o.OrderID = od.OrderID
# LEFT JOIN Products p on od.ProductID = p.ProductID
# LEFT JOIN Categories ca on p.CategoryID = ca.CategoryID
# LEFT JOIN Customers cu on o.CustomerID = cu.CustomerID
# WHERE cu.Country = 'Germany' GROUP BY CategoryName;
# Out:
#  * sqlite:///vbo.db
# Done.
# [('Beverages', 20.5),
#  ('Condiments', 34.0),
#  ('Confections', 40.0),
#  ('Dairy Products', 151.64705882352942),
#  ('Grains/Cereals', 22.142857142857142),
#  ('Meat/Poultry', 30.2),
#  ('Produce', 30.75),
#  ('Seafood', 27.09090909090909)]

# %%
# %%sql
# SELECT AVG(Price) FROM Orders o
# LEFT JOIN OrderDetails odr ON o.OrderID = odr.OrderID
# LEFT JOIN Products p ON odr.ProductID = p.ProductID
# LEFT JOIN Categories ca ON ca.CategoryID = p.CategoryID
# Left JOIN Customers cus ON Cus.CustomerID = o.CustomerID
# Where cus.Country = "Germany" OR cus.Country = "USA" GROUP BY CategoryName;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(29.88888888888889,),
#  (34.72727272727273,),
#  (39.92307692307692,),
#  (131.75862068965517,),
#  (29.846153846153847,),
#  (46.75,),
#  (28.625,),
#  (25.6,)]

# %%
# %%sql
# SELECT ca.CategoryName, AVG(p.Price)
# FROM Orders o
# LEFT JOIN OrderDetails od on o.OrderID = od.OrderID
# LEFT JOIN Products p on od.ProductID = p.ProductID
# LEFT JOIN Categories ca on p.CategoryID = ca.CategoryID
# LEFT JOIN Customers cu on o.CustomerID = cu.CustomerID
# WHERE cu.Country = 'Germany' OR cu.Country = 'USA' GROUP BY CategoryName;
# Out:
#  * sqlite:///vbo.db
# Done.
# [('Beverages', 29.88888888888889),
#  ('Condiments', 34.72727272727273),
#  ('Confections', 39.92307692307692),
#  ('Dairy Products', 131.75862068965517),
#  ('Grains/Cereals', 29.846153846153847),
#  ('Meat/Poultry', 46.75),
#  ('Produce', 28.625),
#  ('Seafood', 25.6)]

# %%
# %%sql
# SELECT AVG(p.Price) FROM Orders o
# LEFT JOIN OrderDetails od ON o.OrderID = od.OrderID
# LEFT JOIN Products p ON p.ProductId = od.ProductID
# WHERE o.OrderDate like "%07%" or o.OrderDate like "%08%" or o.OrderDate like "%09%";
# Out:
#  * sqlite:///vbo.db
# Done.
# [(39.71891891891892,)]

# %%
# %%sql
# SELECT AVG(Products.Price)
# FROM Products
# LEFT JOIN OrderDetails on OrderDetails.ProductID = products.ProductID
# LEFT JOIN Orders on OrderDetails.OrderID = Orders.OrderID
# WHERE OrderDate like '%07%' or OrderDate like '%08%' or OrderDate like '%09%';
# Out:
#  * sqlite:///vbo.db
# Done.
# [(39.71891891891892,)]
